# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 2 main datatypes
# 1. Series
# 2. Dataframe

# %%
#Series =  1D
series = pd.Series(['BMW', 'AUDI', 'HONDA'])
series
# Out:
# 0      BMW
# 1     AUDI
# 2    HONDA
# dtype: object

# %%
colours = pd.Series(['Red', "White", "Blue"])
colours
# Out:
# 0      Red
# 1    White
# 2     Blue
# dtype: object

# %%
#Dataframe = 2D (Takes dictionary)
dataframe = pd.DataFrame({'Colours':colours, "Car":series})
dataframe
# Out:
#   Colours    Car
# 0     Red    BMW
# 1   White   AUDI
# 2    Blue  HONDA

# %%
data = pd.read_csv('/content/drive/MyDrive/ai_dataset/car-sales.csv')
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
data.to_csv("exported_car_sales", index = False)
df = pd.read_csv("exported_car_sales")
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Describe Data

# %%
#data-type
data.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
#column
data.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = data.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
data.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
data.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
df = pd.Series([1000,12000,1300])
df.mean()
# Out:
# 4766.666666666667

# %%
data.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
data["Doors"].sum()
# Out:
# 40

# %%
len(data)
# Out:
# 10

# %%
data.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
data.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
data.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
#loc(location) and iloc(position)
#loc refers to index
animals = pd.Series(["cat", "dog","tiger","snake","bird"], index = [0,3,9,8,3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9    tiger
# 8    snake
# 3     bird
# dtype: object

# %% [markdown]
# # Viewing and Describing Data

# %%
animals.loc[3]
# Out:
# 3     dog
# 3    bird
# dtype: object

# %%
animals.loc[9]
# Out:
# 'tiger'

# %%
data.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9    tiger
# 8    snake
# 3     bird
# dtype: object

# %%
#iloc refers to position

animals.iloc[3]
# Out:
# 'snake'

# %%
#here iloc is used for slicing, returns element upto position 3 (3 isn't included)
animals.iloc[:3]
# Out:
# 0      cat
# 3      dog
# 9    tiger
# dtype: object

# %%
df.loc[:3]
# Out:
# 0     1000
# 1    12000
# 2     1300
# dtype: int64

# %%
data["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
data.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
data["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
data[data["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
#crosstab used for comparison between columns

pd.crosstab(data["Make"], data["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# groupby
data.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# .plot() is for numeric data only, it gives error for non-numeric data

data["Odometer (KM)"].plot()

# %%
data["Odometer (KM)"].hist()

# %%
data["Price"] = data["Price"].str.replace('[\$\,\.]', '').astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
data["Price"].plot()

# %% [markdown]
# # Manipulating Data

# %%
data["Make"].str.lower()

#it doesn't save to our dataset
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
data["Make"] = data["Make"].str.lower()

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing["Odometer"] =  car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
#inplace in another way to assign new value to a dataset(if inplace = true)
car_sales_missing.dropna(inplace = True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv('car-sales-missing-data.csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.dropna(inplace = True)
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing.to_csv("car-sales-missing-dropped.csv")

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
#column from series
seats_column = pd.Series([5,5,5,5,5])

#new column called seats
data["seats"] = seats_column
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    NaN
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
data["seats"].fillna(5,inplace = True)
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price seats
# 0  toyota  White         150043      4   400000   5.0
# 1   honda    Red          87899      4   500000   5.0
# 2  toyota   Blue          32549      3   700000   5.0
# 3     bmw  Black          11179      5  2200000   5.0
# 4  nissan  White         213095      4   350000   5.0
# 5  toyota  Green          99213      4   450000     5
# 6   honda   Blue          45698      4   750000     5
# 7   honda   Blue          54738      4   700000     5
# 8  toyota  White          60000      4   625000     5
# 9  nissan  White          31600      4   970000     5

# %%
# column from Python list
fuel_economy = [7.5, 12.1, 10.9, 5.6, 8.9, 12, 11, 14, 15, 10.3]
data['Fuel per 100km'] = fuel_economy
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price seats  Fuel per 100km
# 0  toyota  White         150043      4   400000   5.0             7.5
# 1   honda    Red          87899      4   500000   5.0            12.1
# 2  toyota   Blue          32549      3   700000   5.0            10.9
# 3     bmw  Black          11179      5  2200000   5.0             5.6
# 4  nissan  White         213095      4   350000   5.0             8.9
# 5  toyota  Green          99213      4   450000     5            12.0
# 6   honda   Blue          45698      4   750000     5            11.0
# 7   honda   Blue          54738      4   700000     5            14.0
# 8  toyota  White          60000      4   625000     5            15.0
# 9  nissan  White          31600      4   970000     5            10.3

# %%
#column from another column
data["Total fuel used(L)"] = data["Odometer (KM)"]/100*data["Fuel per 100km"]
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price seats  Fuel per 100km  \
# 0  toyota  White         150043      4   400000   5.0             7.5
# 1   honda    Red          87899      4   500000   5.0            12.1
# 2  toyota   Blue          32549      3   700000   5.0            10.9
# 3     bmw  Black          11179      5  2200000   5.0             5.6
# 4  nissan  White         213095      4   350000   5.0             8.9
# 5  toyota  Green          99213      4   450000     5            12.0
# 6   honda   Blue          45698      4   750000     5            11.0
# 7   honda   Blue          54738      4   700000     5            14.0
# 8  toyota  White          60000      4   625000     5            15.0
# 9  nissan  White          31600      4   970000     5            10.3
#
#    Total fuel used  Total fuel used(L)
# 0        11253.225           11253.225
# 1        10635.779           10635.779
# 2         3547.841            3547.841
# ...

# %%
#create a column from a single value
data['Number of wheels'] = 4
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price seats  Fuel per 100km  \
# 0  toyota  White         150043      4   400000   5.0             7.5
# 1   honda    Red          87899      4   500000   5.0            12.1
# 2  toyota   Blue          32549      3   700000   5.0            10.9
# 3     bmw  Black          11179      5  2200000   5.0             5.6
# 4  nissan  White         213095      4   350000   5.0             8.9
# 5  toyota  Green          99213      4   450000     5            12.0
# 6   honda   Blue          45698      4   750000     5            11.0
# 7   honda   Blue          54738      4   700000     5            14.0
# 8  toyota  White          60000      4   625000     5            15.0
# 9  nissan  White          31600      4   970000     5            10.3
#
#    Total fuel used  Total fuel used(L)  Number of wheels
# 0        11253.225           11253.225                 4
# 1        10635.779           10635.779                 4
# ...

# %%
data['Passed road Safety'] = True
data.dtypes
# Out:
# Make                   object
# Colour                 object
# Odometer (KM)           int64
# Doors                   int64
# Price                   int64
# seats                  object
# Fuel per 100km        float64
# Total fuel used       float64
# Total fuel used(L)    float64
# Number of wheels        int64
# Passed road Safety       bool
# dtype: object

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price seats  Fuel per 100km  \
# 0  toyota  White         150043      4   400000   5.0             7.5
# 1   honda    Red          87899      4   500000   5.0            12.1
# 2  toyota   Blue          32549      3   700000   5.0            10.9
# 3     bmw  Black          11179      5  2200000   5.0             5.6
# 4  nissan  White         213095      4   350000   5.0             8.9
# 5  toyota  Green          99213      4   450000     5            12.0
# 6   honda   Blue          45698      4   750000     5            11.0
# 7   honda   Blue          54738      4   700000     5            14.0
# 8  toyota  White          60000      4   625000     5            15.0
# 9  nissan  White          31600      4   970000     5            10.3
#
#    Total fuel used  Total fuel used(L)  Number of wheels  Passed road Safety
# 0        11253.225           11253.225                 4                True
# ...

# %%
data.drop("Total fuel used", axis = 1,inplace = True)
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price seats  Fuel per 100km  \
# 0  toyota  White         150043      4   400000   5.0             7.5
# 1   honda    Red          87899      4   500000   5.0            12.1
# 2  toyota   Blue          32549      3   700000   5.0            10.9
# 3     bmw  Black          11179      5  2200000   5.0             5.6
# 4  nissan  White         213095      4   350000   5.0             8.9
# 5  toyota  Green          99213      4   450000     5            12.0
# 6   honda   Blue          45698      4   750000     5            11.0
# 7   honda   Blue          54738      4   700000     5            14.0
# 8  toyota  White          60000      4   625000     5            15.0
# 9  nissan  White          31600      4   970000     5            10.3
#
#    Total fuel used(L)  Number of wheels  Passed road Safety
# 0           11253.225                 4                True
# 1           10635.779                 4                True
# ...

# %%
#samples of data
data.sample(frac = 0.5)      #0.5 means 50% of data but data maybe in random order
# Out:
#      Make Colour  Odometer (KM)  Doors   Price seats  Fuel per 100km  \
# 7   honda   Blue          54738      4  700000     5            14.0
# 0  toyota  White         150043      4  400000   5.0             7.5
# 1   honda    Red          87899      4  500000   5.0            12.1
# 9  nissan  White          31600      4  970000     5            10.3
# 8  toyota  White          60000      4  625000     5            15.0
#
#    Total fuel used(L)  Number of wheels  Passed road Safety
# 7            7663.320                 4                True
# 0           11253.225                 4                True
# 1           10635.779                 4                True
# 9            3254.800                 4                True
# 8            9000.000                 4                True

# %%
car_sales_shuffled=data.sample(frac = 1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price seats  Fuel per 100km  \
# 2  toyota   Blue          32549      3   700000   5.0            10.9
# 8  toyota  White          60000      4   625000     5            15.0
# 0  toyota  White         150043      4   400000   5.0             7.5
# 5  toyota  Green          99213      4   450000     5            12.0
# 1   honda    Red          87899      4   500000   5.0            12.1
# 4  nissan  White         213095      4   350000   5.0             8.9
# 9  nissan  White          31600      4   970000     5            10.3
# 3     bmw  Black          11179      5  2200000   5.0             5.6
# 6   honda   Blue          45698      4   750000     5            11.0
# 7   honda   Blue          54738      4   700000     5            14.0
#
#    Total fuel used(L)  Number of wheels  Passed road Safety
# 2            3547.841                 4                True
# 8            9000.000                 4                True
# ...

# %%
#only select 20% of data for big datasets
car_sales_shuffled.sample(frac = 0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price seats  Fuel per 100km  \
# 2  toyota   Blue          32549      3  700000   5.0            10.9
# 6   honda   Blue          45698      4  750000     5            11.0
#
#    Total fuel used(L)  Number of wheels  Passed road Safety
# 2            3547.841                 4                True
# 6            5026.780                 4                True

# %%
#reset_index resets the shuffled data 
car_sales_shuffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price seats  Fuel per 100km  \
# 0      2  toyota   Blue          32549      3   700000   5.0            10.9
# 1      8  toyota  White          60000      4   625000     5            15.0
# 2      0  toyota  White         150043      4   400000   5.0             7.5
# 3      5  toyota  Green          99213      4   450000     5            12.0
# 4      1   honda    Red          87899      4   500000   5.0            12.1
# 5      4  nissan  White         213095      4   350000   5.0             8.9
# 6      9  nissan  White          31600      4   970000     5            10.3
# 7      3     bmw  Black          11179      5  2200000   5.0             5.6
# 8      6   honda   Blue          45698      4   750000     5            11.0
# 9      7   honda   Blue          54738      4   700000     5            14.0
#
#    Total fuel used(L)  Number of wheels  Passed road Safety
# 0            3547.841                 4                True
# ...

# %%
car_sales_shuffled.reset_index(drop = True, inplace = True)   #drop = Ture is for removing shuffled index column
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price seats  Fuel per 100km  \
# 0  toyota   Blue          32549      3   700000   5.0            10.9
# 1  toyota  White          60000      4   625000     5            15.0
# 2  toyota  White         150043      4   400000   5.0             7.5
# 3  toyota  Green          99213      4   450000     5            12.0
# 4   honda    Red          87899      4   500000   5.0            12.1
# 5  nissan  White         213095      4   350000   5.0             8.9
# 6  nissan  White          31600      4   970000     5            10.3
# 7     bmw  Black          11179      5  2200000   5.0             5.6
# 8   honda   Blue          45698      4   750000     5            11.0
# 9   honda   Blue          54738      4   700000     5            14.0
#
#    Total fuel used(L)  Number of wheels  Passed road Safety
# 0            3547.841                 4                True
# 1            9000.000                 4                True
# ...

# %%
#conversion of odometer (km) to miles by apply() function

data["Odometer (KM)"] = data["Odometer (KM)"].apply(lambda x: x/1.6)
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price seats  Fuel per 100km  \
# 0  toyota  White      93776.875      4   400000   5.0             7.5
# 1   honda    Red      54936.875      4   500000   5.0            12.1
# 2  toyota   Blue      20343.125      3   700000   5.0            10.9
# 3     bmw  Black       6986.875      5  2200000   5.0             5.6
# 4  nissan  White     133184.375      4   350000   5.0             8.9
# 5  toyota  Green      62008.125      4   450000     5            12.0
# 6   honda   Blue      28561.250      4   750000     5            11.0
# 7   honda   Blue      34211.250      4   700000     5            14.0
# 8  toyota  White      37500.000      4   625000     5            15.0
# 9  nissan  White      19750.000      4   970000     5            10.3
#
#    Total fuel used(L)  Number of wheels  Passed road Safety
# 0           11253.225                 4                True
# 1           10635.779                 4                True
# ...
